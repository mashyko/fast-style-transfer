# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive

# %%
#!git clone https://github.com/lengstrom/fast-style-transfer.git

# %%
# %cd fast-style-transfer
# Out:
# /content/drive/My Drive/fast-style-transfer

# %% [markdown]
# It is neccessary to downgrade scipy == 1.1.0 .
#
# the code in evaluate.py and transform.py was modified so as to run for Tensorflow 2.0 but not for Tensorflow 1.x.

# %%
# !pip install scipy==1.1.0
#!python -m pip install pillow

from matplotlib.pyplot import imread
# !python evaluate.py --checkpoint ./ckpt/wave.ckpt  --in-path ./examples/content/enoshima_2.jpg --out-path ./examples/results/enoshima_wave.jpg
# Out:
# ...
# 2020-03-18 08:31:11.481763: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-18 08:31:11.481980: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x20892c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-18 08:31:11.482016: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-18 08:31:11.483839: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-18 08:31:11.563195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-18 08:31:11.564092: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2089d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# ...
